# %%
import turtle

wn = turtle.Screen()
wn.bgcolor("black")
wn.title("A Vacuum Cleaner Game")
wn.setup(700,700)

# Create Pen

class Pen(turtle.Turtle):

  def __init__(self):
    turtle.Turtle.__init__(self)
    self.shape("square")
    self.color("white")
    self.penup()
    self.speed(0)
    
class Player(turtle.Turtle):
  def __init__(self):
    turtle.Turtle.__init__(self)
    self.shape("square")
    self.color("green")
    self.penup()
    self.speed(0)
    
class Dirt(turtle.Turtle):
  def __init__(self):
    turtle.Turtle.__init__(self)
    self.shape("square")
    self.color("blue")
    self.penup()
    self.speed(0)

# Create levels list
levels = [""]

# Define first level 
level_1 = [
    "XXXXXXXXXXXXXXXXXXXXXXXXX",
    "XV XXXXXXX          XXXXX",
    "X  XXXXXXX  XXXXXX  XXXXX",
    "X       XX  XXXXXX  XXXXX",
    "X  D    XX  XXX        XX",
    "X       XX  XXX        XX",
    "X      DXX  XXXX       XX",
    "X        X     X   D   XX",
    "XX    XXXXXX  XX      XXX",
    "X   XXXXX     XX      XXX",
    "X  XXXXX    XXXX      XXX",
    "X          XXXXXX     XXX",
    "X          XXXXXX     XXX",
    "X  D       XXXXXX     XXX",
    "X                     XXX",
    "X               XXXXXXXXX",
    "X               XXXXXXXXX",
    "X      D        XXXXXXXXX",
    "X               XXXXXXXXX",
    "X  D            XXXXXXXXX",
    "X               XXXXXXXXX",
    "X          D    XXXXXXXXX",
    "X              D       XX",
    "X                      XX",
    "XXXXXXXXXXXXXXXXXXXXXXXXX"
]

# Add maze to mazes list
levels.append(level_1)

# Create Level Setup Function

def setup_maze(level):
  for y in range(len(level)):
    for x in range(len(level[y])):
      # Get the character at each x,y coordinate
      #NOTE the order of y and x in the next line
      character = level[y][x]
      # Calculate the screen x,y coordinatexs
      screen_x = -288 + (x*24)
      screen_y = 288 - (y*24)
        
      # Check if it is an X (representing a wall)
      if character == "X":
        pen.goto(screen_x, screen_y)
        pen.stamp()
      if character == "V":
        player.goto(screen_x, screen_y)
      if character == "D":
        dirt.goto(screen_x, screen_y)
        pen.stamp()
        
      # Add things for dirt and unknowns here

# Create instance of the class
pen = Pen()
player = Player()
dirt = Dirt()

# Setup the level
setup_maze(levels[1])

# Main Game Loop
while True:
  pass
